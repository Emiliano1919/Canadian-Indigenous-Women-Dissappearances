# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.cbc.ca/missingandmurdered/'
website = requests.get(url)
soup = BeautifulSoup(website.text,'html')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="www.cbc.ca" name="application-name"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="/favicon.ico" rel="shortcut icon" type="image/ico"/>
# <meta content="App" name="msApplication-ID"/>
# <meta content="CanadianBroadcastingCorpo.CBC_pw8q9bvavk68p" name="msApplication-PackageFamilyName"/>
# <meta content="The unsolved cases of Canada's missing and murdered aboriginal women and girls." name="description"/>
# <link href="https://www.cbc.ca/missingandmurdered/templates/default_site/mmiw.group/news2/interactives/fonts/font-stag.css" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans" rel="stylesheet"/>
# <!-- *** THESE FILES WILL BE MINIFIED AND COMBINED *** -->
# ...

# %%
soup.find_all('div',class_='facewall')
# Out:
# [<div class="facewall" id="mmiw-facewall">
#  <ul class="entries" id="mmiw-listing">
#  </ul>
#  </div>]

# %%
#This does not work the webpage is dynamic we will use selenium
