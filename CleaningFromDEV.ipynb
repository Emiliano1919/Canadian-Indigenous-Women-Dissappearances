# %%
df = pd.read_excel('Updated_From_DEV.xlsx') 
print(df.columns)
df
# Out:
# Index(['Name', 'Age', 'Province', 'Status', 'First-Name', 'Last-Name',
#        'LS-Latitude', 'LS-Longitude', 'LS-Location Source', 'F-Latitude',
#        'F-Longitude', 'F-Location Source', 'F-Year', 'F-Month', 'F-Day',
#        'LS-Year', 'LS-Month', 'LS-Day', 'Highway-16', 'Serial Killer',
#        'Non-Dissapearance', 'LS-Location', 'F-Location', 'LS-General-Location',
#        'F-General-Location', 'LS-Dubious Source', 'Extra'],
#       dtype='object')
#                    Name   Age Province     Status First-Name    Last-Name  \
# 0       Abigail Andrews    28       BC    Missing    Abigail      Andrews
# 1             Ada Brown    41      N/A   Murdered        Ada        Brown
# 2    Aielah Saric-Auger    14       BC   Murdered     Aielah  Saric-Auger
# 3      Alannah Cardinal    20       AB   Murdered    Alannah     Cardinal
# 4      Alberta Williams    24       BC   Murdered    Alberta     Williams
# ..                  ...   ...      ...        ...        ...          ...
# 302  Victoria Crow Shoe    43      N/A   Murdered   Victoria    Crow Shoe
# 303  Victoria Hornbrook   N/A       MB   Murdered   Victoria    Hornbrook
# 304    Viola Panacheese    42       ON    Missing      Viola   Panacheese
# 305      Violet Heathen    49       AB   Murdered     Violet      Heathen
# 306         Wendy Poole    20       BC   Murdered      Wendy        Poole
#
#      LS-Latitude  LS-Longitude  \
# 0      56.240344   -120.835879
# 1       0.000000      0.000000
# 2      53.897478   -122.777436
# 3      54.300895   -111.833420
# 4      54.308600   -130.333923
# ..           ...           ...
# 302     0.000000      0.000000
# 303     0.000000      0.000000
# 304     0.000000      0.000000
# 305     0.000000      0.000000
# 306     0.000000      0.000000
#
#                                     LS-Location Source  F-Latitude  ...  \
# 0    https://storiesoftheunsolved.com/2020/02/03/th...    0.000000  ...
# 1                                                  NaN   53.915868  ...
# 2          https://thehueandcry.com/aielah-saric-auger   53.945427  ...
# 3    https://www.cbc.ca/missingandmurdered/mmiw/pro...   54.300895  ...
# 4            https://thehueandcry.com/alberta-williams   54.298882  ...
# ..                                                 ...         ...  ...
# 302                                                NaN    0.000000  ...
# 303                                                NaN    0.000000  ...
# 304                                                NaN    0.000000  ...
# 305                                                NaN    0.000000  ...
# 306                                                NaN    0.000000  ...
#
#      LS-Day Highway-16  Serial Killer  Non-Dissapearance  LS-Location  \
# 0         7          0              0                  0          NaN
# 1         0          0              0                  0          NaN
# 2         2          1              0                  0          NaN
# 3        16          0              0                  0          NaN
# 4        25          1              0                  0          NaN
# ..      ...        ...            ...                ...          ...
# 302       0          0              0                  0          NaN
# 303       0          0              0                  0          NaN
# 304       0          0              0                  0          NaN
# 305       0          0              0                  0          NaN
# 306       0          0              0                  0          NaN
#
#      F-Location                                LS-General-Location  \
# 0           NaN           94th Ave, Fort St John, British Columbia
# 1           NaN                                                NaN
# 2           NaN  Pine Centre Mall, Prince George, British Columbia
# 3           NaN             Whitefish (Goodfish) Lake First Nation
# 4           NaN  Bogey’s Cabaret, Second Avenue West, Prince Ru...
# ..          ...                                                ...
# 302         NaN                                                NaN
# 303         NaN                                                NaN
# 304         NaN                                                NaN
# 305         NaN                                                NaN
# 306         NaN                                                NaN
#
#                                     F-General-Location  LS-Dubious Source  \
# 0                                                  NaN                NaN
# 1    Hotel in Prince George, British Columbia (No d...                NaN
# 2                   Highway 16 ditch near Tabor Nation                NaN
# 3               Whitefish (Goodfish) Lake First Nation                NaN
# 4    East of Prince Rupert on Highway 16, British C...                NaN
# ..                                                 ...                ...
# 302                                                NaN                NaN
# 303                                                NaN                NaN
# 304                                                NaN                NaN
# 305                                                NaN                NaN
# 306                                                NaN                NaN
#
#      Extra
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 302    NaN
# 303    NaN
# 304    NaN
# 305    NaN
# 306    NaN
#
# [307 rows x 27 columns]

# %%
df.iloc[18]
# Out:
# Name                                                       Angeline Pete
# Age                                                                   28
# Province                                                              BC
# Status                                                           Missing
# First-Name                                                      Angeline
# Last-Name                                                           Pete
# LS-Latitude                                                    49.319871
# LS-Longitude                                                 -123.071587
# LS-Location Source     https://www.cbc.ca/missingandmurdered/mmiw/pro...
# F-Latitude                                                           0.0
# F-Longitude                                                          0.0
# F-Location Source                                                    NaN
# F-Year                                                                 0
# F-Month                                                                0
# F-Day                                                                  0
# LS-Year                                                             2011
# LS-Month                                                               5
# LS-Day                                                                26
# Highway-16                                                             0
# Serial Killer                                                          0
# Non-Dissapearance                                                      0
# LS-Location                                                          NaN
# F-Location                                                           NaN
# LS-General-Location                    North Vancouver, British Columbia
# F-General-Location                                                   NaN
# LS-Dubious Source                                                    NaN
# Extra                                                                NaN
# Name: 18, dtype: object

# %%
start_index = 19
mask = df.index >= start_index
df.loc[mask, 'LS-Latitude'] = df.loc[mask, 'LS-Location'].str.split(',', expand=True)[0].str.strip().astype(float)
df.loc[mask, 'LS-Longitude'] = df.loc[mask, 'LS-Location'].str.split(',', expand=True)[1].str.strip().astype(float)
print(df.head(24))
# Out:
#                     Name   Age Province     Status First-Name     Last-Name  \
# 0        Abigail Andrews    28       BC    Missing    Abigail       Andrews
# 1              Ada Brown    41      N/A   Murdered        Ada         Brown
# 2     Aielah Saric-Auger    14       BC   Murdered     Aielah   Saric-Auger
# 3       Alannah Cardinal    20       AB   Murdered    Alannah      Cardinal
# 4       Alberta Williams    24       BC   Murdered    Alberta      Williams
# 5      Alice Netemegesic   N/A       ON   Murdered      Alice   Netemegesic
# 6        Alisha Germaine    15       BC   Murdered     Alisha      Germaine
# 7            Amanda Cook    14       MB   Murdered     Amanda          Cook
# 8         Amanda Simpson     4       BC   Murdered     Amanda       Simpson
# 9        Amanda Bartlett    17       MB    Missing     Amanda      Bartlett
# 10         Amber Tuccaro    20       AB   Murdered      Amber       Tuccaro
# 11        Amber Guiboche    20       MB    Missing      Amber      Guiboche
# 12          Andria Meise    32       BC    Missing     Andria         Meise
# 13  Annette Holywhiteman    44       AB   Murdered    Annette  Holywhiteman
# 14         Angel Carlick    19       YT   Murdered      Angel       Carlick
# 15          Angela Meyer    22       NT    Missing     Angela         Meyer
# 16       Angela Williams    31       BC   Murdered     Angela      Williams
# 17        Angela Poorman    29       MB   Murdered     Angela       Poorman
# 18         Angeline Pete    28       BC    Missing   Angeline          Pete
# 19           Anne Peters    22       BC    Missing       Anne        Peters
# 20      Annie Pootoogook    46       ON   Murdered      Annie    Pootoogook
# 21          Annie Yassie    13       MB    Missing      Annie        Yassie
# 22    Ashley Machiskinic    22       BC   Murdered     Ashley   Machiskinic
# 23     Audrey Desjarlais   N/A       MB   Murdered     Audrey    Desjarlais
#
#     LS-Latitude  LS-Longitude  \
# 0     56.240344   -120.835879
# 1      0.000000      0.000000
# 2     53.897478   -122.777436
# 3     54.300895   -111.833420
# 4     54.308600   -130.333923
# 5      0.000000      0.000000
# 6     53.919380   -122.752203
# 7     50.674501   -100.815511
# 8     53.912105   -122.763977
# 9     49.914662    -97.141429
# 10    53.337682   -113.524071
# 11    49.902254    -97.149372
# 12    55.171054   -118.793169
# 13    53.545815   -113.496899
# 14    60.719077   -135.056320
# 15    62.444673   -114.370832
# 16    49.280614   -123.119859
# 17    49.915669    -97.145396
# 18    49.319871   -123.071587
# 19    49.134553   -122.308595
# 20    45.432027    -75.688449
# 21    58.767995    -94.164067
# 22    49.286033   -123.120352
# 23    49.530572    -96.688988
#
#                                    LS-Location Source  F-Latitude  ...  \
# 0   https://storiesoftheunsolved.com/2020/02/03/th...    0.000000  ...
# 1                                                 NaN   53.915868  ...
# 2         https://thehueandcry.com/aielah-saric-auger   53.945427  ...
# 3   https://www.cbc.ca/missingandmurdered/mmiw/pro...   54.300895  ...
# 4           https://thehueandcry.com/alberta-williams   54.298882  ...
# 5                                                 NaN   48.382379  ...
# 6   https://www.cbc.ca/missingandmurdered/mmiw/pro...   53.835539  ...
# 7   https://www.cbc.ca/missingandmurdered/mmiw/pro...   50.674501  ...
# 8   https://www.cbc.ca/missingandmurdered/mmiw/pro...   49.244424  ...
# 9   https://www.cbc.ca/missingandmurdered/mmiw/pro...    0.000000  ...
# 10  https://www.cbc.ca/missingandmurdered/mmiw/pro...   53.337682  ...
# 11  https://www.cbc.ca/missingandmurdered/mmiw/pro...    0.000000  ...
# 12  https://www.cbc.ca/missingandmurdered/mmiw/pro...    0.000000  ...
# 13  https://www.cbc.ca/missingandmurdered/mmiw/pro...   54.159175  ...
# 14  https://www.rcmp-grc.gc.ca/en/news/2023/yukon-...   61.031175  ...
# 15  https://discover.hubpages.com/politics/angela-...    0.000000  ...
# 16  https://www.cbc.ca/missingandmurdered/mmiw/pro...   49.113672  ...
# 17  https://www.cbc.ca/missingandmurdered/mmiw/pro...   49.915669  ...
# 18  https://www.cbc.ca/missingandmurdered/mmiw/pro...    0.000000  ...
# 19  https://www.aboriginalalert.ca/missingpersons/...    0.000000  ...
# 20  https://nunatsiaq.com/stories/article/65674inu...    0.000000  ...
# 21  https://www.cbc.ca/missingandmurdered/mmiw/pro...    0.000000  ...
# 22  https://www.cbc.ca/missingandmurdered/mmiw/pro...    0.000000  ...
# 23  https://www.cbc.ca/missingandmurdered/mmiw/pro...    0.000000  ...
#
#     LS-Day Highway-16  Serial Killer  Non-Dissapearance  \
# 0        7          0              0                  0
# 1        0          0              0                  0
# 2        2          1              0                  0
# 3       16          0              0                  0
# 4       25          1              0                  0
# 5        0          0              0                  0
# 6        9          1              0                  0
# 7       13          0              0                  0
# 8       30          0              0                  1
# 9        0          0              0                  0
# 10      18          0              0                  0
# 11      10          0              0                  0
# 12       0          0              0                  0
# 13       0          0              0                  0
# 14      27          0              0                  0
# 15      27          0              0                  0
# 16       0          0              0                  0
# 17      14          0              0                  1
# 18      26          0              0                  0
# 19      11          0              0                  0
# 20      18          0              0                  0
# 21      22          0              0                  0
# 22      15          0              0                  0
# 23       0          0              0                  0
#
#                                 LS-Location  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                       NaN
# 10                                      NaN
# 11                                      NaN
# 12                                      NaN
# 13                                      NaN
# 14                                      NaN
# 15                                      NaN
# 16                                      NaN
# 17                                      NaN
# 18                                      NaN
# 19   49.13455304245581, -122.30859521464839
# 20    45.43202674905499, -75.68844883262602
# 21    58.76799512600049, -94.16406713849813
# 22  49.286033097460795, -123.12035191195747
# 23    49.53057157142498, -96.68898843682356
#
#                                  F-Location  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                       NaN
# 10                                      NaN
# 11                                      NaN
# 12                                      NaN
# 13                                      NaN
# 14                                      NaN
# 15                                      NaN
# 16                                      NaN
# 17                                      NaN
# 18                                      NaN
# 19                                      NaN
# 20   45.434144759722585, -75.67217126612498
# 21                                      NaN
# 22  49.286033097460795, -123.12035191195747
# 23    49.85624102379149, -97.12579229286627
#
#                                   LS-General-Location  \
# 0            94th Ave, Fort St John, British Columbia
# 1                                                 NaN
# 2   Pine Centre Mall, Prince George, British Columbia
# 3              Whitefish (Goodfish) Lake First Nation
# 4   Bogey’s Cabaret, Second Avenue West, Prince Ru...
# 5                                                 NaN
# 6   Native Friendship Centre, Prince George, Briti...
# 7                          Waywayseecapo First Nation
# 8   A hospital in Prince George, British Columbia ...
# 9               Selkirk Ave & Salter Street, Winnipeg
# 10                        Nisku, Alberta (No details)
# 11           William Ave & Isabelle St Area, Winnipeg
# 12                Grand Prairie, Alberta (No details)
# 13                     Edmonton, Alberta (No details)
# 14                                  Whitehorse, Yukon
# 15  Forrest Drive & Con Road, Yellowknife, Norther...
# 16                             Vancouver (No details)
# 17                               Winnipeg’s North End
# 18                  North Vancouver, British Columbia
# 19                          Mission, British Columbia
# 20             Shepherds of Good Hope shelter, Ottawa
# 21                                Churchill, Manitoba
# 22                  Regent hotel, Vancouver East Side
# 23                                Steinbach, Manitoba
#
#                                    F-General-Location  LS-Dubious Source  \
# 0                                                 NaN                NaN
# 1   Hotel in Prince George, British Columbia (No d...                NaN
# 2                  Highway 16 ditch near Tabor Nation                NaN
# 3              Whitefish (Goodfish) Lake First Nation                NaN
# 4   East of Prince Rupert on Highway 16, British C...                NaN
# 5                                Thunder Bay, Ontario                NaN
# 6   Haldi Road Elementary School, Prince George, B...                NaN
# 7                          Waywayseecapo First Nation                NaN
# 8    A hospital in Prince George, British Columbia...                NaN
# 9                                                 NaN                NaN
# 10                         Nisku, Alberta(No details)                NaN
# 11                                                NaN                NaN
# 12                                                NaN                NaN
# 13                             Near Westlock, Alberta                NaN
# 14  Pilot Mountain Subdivision, Outside Whitehorse...                NaN
# 15                                                NaN                NaN
# 16  Ditch on a rural road Surrey, British Columbia...                NaN
# 17                               Winnipeg's North End                NaN
# 18                                                NaN                NaN
# 19                                                NaN                NaN
# 20              Rideau River near the shelter, Ottawa                NaN
# 21                                                NaN                NaN
# 22                  Regent Hotel, Vancouver East Side                NaN
# 23                                Winnipeg, red river                NaN
#
#     Extra
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
#
# [24 rows x 27 columns]

# %%
start_index = 19
mask = df.index >= start_index
df.loc[mask, 'F-Latitude'] = df.loc[mask, 'F-Location'].str.split(',', expand=True)[0].str.strip().astype(float)
df.loc[mask, 'F-Longitude'] = df.loc[mask, 'F-Location'].str.split(',', expand=True)[1].str.strip().astype(float)
print(df.head(24))
# Out:
#                     Name   Age Province     Status First-Name     Last-Name  \
# 0        Abigail Andrews    28       BC    Missing    Abigail       Andrews
# 1              Ada Brown    41      N/A   Murdered        Ada         Brown
# 2     Aielah Saric-Auger    14       BC   Murdered     Aielah   Saric-Auger
# 3       Alannah Cardinal    20       AB   Murdered    Alannah      Cardinal
# 4       Alberta Williams    24       BC   Murdered    Alberta      Williams
# 5      Alice Netemegesic   N/A       ON   Murdered      Alice   Netemegesic
# 6        Alisha Germaine    15       BC   Murdered     Alisha      Germaine
# 7            Amanda Cook    14       MB   Murdered     Amanda          Cook
# 8         Amanda Simpson     4       BC   Murdered     Amanda       Simpson
# 9        Amanda Bartlett    17       MB    Missing     Amanda      Bartlett
# 10         Amber Tuccaro    20       AB   Murdered      Amber       Tuccaro
# 11        Amber Guiboche    20       MB    Missing      Amber      Guiboche
# 12          Andria Meise    32       BC    Missing     Andria         Meise
# 13  Annette Holywhiteman    44       AB   Murdered    Annette  Holywhiteman
# 14         Angel Carlick    19       YT   Murdered      Angel       Carlick
# 15          Angela Meyer    22       NT    Missing     Angela         Meyer
# 16       Angela Williams    31       BC   Murdered     Angela      Williams
# 17        Angela Poorman    29       MB   Murdered     Angela       Poorman
# 18         Angeline Pete    28       BC    Missing   Angeline          Pete
# 19           Anne Peters    22       BC    Missing       Anne        Peters
# 20      Annie Pootoogook    46       ON   Murdered      Annie    Pootoogook
# 21          Annie Yassie    13       MB    Missing      Annie        Yassie
# 22    Ashley Machiskinic    22       BC   Murdered     Ashley   Machiskinic
# 23     Audrey Desjarlais   N/A       MB   Murdered     Audrey    Desjarlais
#
#     LS-Latitude  LS-Longitude  \
# 0     56.240344   -120.835879
# 1      0.000000      0.000000
# 2     53.897478   -122.777436
# 3     54.300895   -111.833420
# 4     54.308600   -130.333923
# 5      0.000000      0.000000
# 6     53.919380   -122.752203
# 7     50.674501   -100.815511
# 8     53.912105   -122.763977
# 9     49.914662    -97.141429
# 10    53.337682   -113.524071
# 11    49.902254    -97.149372
# 12    55.171054   -118.793169
# 13    53.545815   -113.496899
# 14    60.719077   -135.056320
# 15    62.444673   -114.370832
# 16    49.280614   -123.119859
# 17    49.915669    -97.145396
# 18    49.319871   -123.071587
# 19    49.134553   -122.308595
# 20    45.432027    -75.688449
# 21    58.767995    -94.164067
# 22    49.286033   -123.120352
# 23    49.530572    -96.688988
#
#                                    LS-Location Source  F-Latitude  ...  \
# 0   https://storiesoftheunsolved.com/2020/02/03/th...    0.000000  ...
# 1                                                 NaN   53.915868  ...
# 2         https://thehueandcry.com/aielah-saric-auger   53.945427  ...
# 3   https://www.cbc.ca/missingandmurdered/mmiw/pro...   54.300895  ...
# 4           https://thehueandcry.com/alberta-williams   54.298882  ...
# 5                                                 NaN   48.382379  ...
# 6   https://www.cbc.ca/missingandmurdered/mmiw/pro...   53.835539  ...
# 7   https://www.cbc.ca/missingandmurdered/mmiw/pro...   50.674501  ...
# 8   https://www.cbc.ca/missingandmurdered/mmiw/pro...   49.244424  ...
# 9   https://www.cbc.ca/missingandmurdered/mmiw/pro...    0.000000  ...
# 10  https://www.cbc.ca/missingandmurdered/mmiw/pro...   53.337682  ...
# 11  https://www.cbc.ca/missingandmurdered/mmiw/pro...    0.000000  ...
# 12  https://www.cbc.ca/missingandmurdered/mmiw/pro...    0.000000  ...
# 13  https://www.cbc.ca/missingandmurdered/mmiw/pro...   54.159175  ...
# 14  https://www.rcmp-grc.gc.ca/en/news/2023/yukon-...   61.031175  ...
# 15  https://discover.hubpages.com/politics/angela-...    0.000000  ...
# 16  https://www.cbc.ca/missingandmurdered/mmiw/pro...   49.113672  ...
# 17  https://www.cbc.ca/missingandmurdered/mmiw/pro...   49.915669  ...
# 18  https://www.cbc.ca/missingandmurdered/mmiw/pro...    0.000000  ...
# 19  https://www.aboriginalalert.ca/missingpersons/...         NaN  ...
# 20  https://nunatsiaq.com/stories/article/65674inu...   45.434145  ...
# 21  https://www.cbc.ca/missingandmurdered/mmiw/pro...         NaN  ...
# 22  https://www.cbc.ca/missingandmurdered/mmiw/pro...   49.286033  ...
# 23  https://www.cbc.ca/missingandmurdered/mmiw/pro...   49.856241  ...
#
#     LS-Day Highway-16  Serial Killer  Non-Dissapearance  \
# 0        7          0              0                  0
# 1        0          0              0                  0
# 2        2          1              0                  0
# 3       16          0              0                  0
# 4       25          1              0                  0
# 5        0          0              0                  0
# 6        9          1              0                  0
# 7       13          0              0                  0
# 8       30          0              0                  1
# 9        0          0              0                  0
# 10      18          0              0                  0
# 11      10          0              0                  0
# 12       0          0              0                  0
# 13       0          0              0                  0
# 14      27          0              0                  0
# 15      27          0              0                  0
# 16       0          0              0                  0
# 17      14          0              0                  1
# 18      26          0              0                  0
# 19      11          0              0                  0
# 20      18          0              0                  0
# 21      22          0              0                  0
# 22      15          0              0                  0
# 23       0          0              0                  0
#
#                                 LS-Location  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                       NaN
# 10                                      NaN
# 11                                      NaN
# 12                                      NaN
# 13                                      NaN
# 14                                      NaN
# 15                                      NaN
# 16                                      NaN
# 17                                      NaN
# 18                                      NaN
# 19   49.13455304245581, -122.30859521464839
# 20    45.43202674905499, -75.68844883262602
# 21    58.76799512600049, -94.16406713849813
# 22  49.286033097460795, -123.12035191195747
# 23    49.53057157142498, -96.68898843682356
#
#                                  F-Location  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                       NaN
# 10                                      NaN
# 11                                      NaN
# 12                                      NaN
# 13                                      NaN
# 14                                      NaN
# 15                                      NaN
# 16                                      NaN
# 17                                      NaN
# 18                                      NaN
# 19                                      NaN
# 20   45.434144759722585, -75.67217126612498
# 21                                      NaN
# 22  49.286033097460795, -123.12035191195747
# 23    49.85624102379149, -97.12579229286627
#
#                                   LS-General-Location  \
# 0            94th Ave, Fort St John, British Columbia
# 1                                                 NaN
# 2   Pine Centre Mall, Prince George, British Columbia
# 3              Whitefish (Goodfish) Lake First Nation
# 4   Bogey’s Cabaret, Second Avenue West, Prince Ru...
# 5                                                 NaN
# 6   Native Friendship Centre, Prince George, Briti...
# 7                          Waywayseecapo First Nation
# 8   A hospital in Prince George, British Columbia ...
# 9               Selkirk Ave & Salter Street, Winnipeg
# 10                        Nisku, Alberta (No details)
# 11           William Ave & Isabelle St Area, Winnipeg
# 12                Grand Prairie, Alberta (No details)
# 13                     Edmonton, Alberta (No details)
# 14                                  Whitehorse, Yukon
# 15  Forrest Drive & Con Road, Yellowknife, Norther...
# 16                             Vancouver (No details)
# 17                               Winnipeg’s North End
# 18                  North Vancouver, British Columbia
# 19                          Mission, British Columbia
# 20             Shepherds of Good Hope shelter, Ottawa
# 21                                Churchill, Manitoba
# 22                  Regent hotel, Vancouver East Side
# 23                                Steinbach, Manitoba
#
#                                    F-General-Location  LS-Dubious Source  \
# 0                                                 NaN                NaN
# 1   Hotel in Prince George, British Columbia (No d...                NaN
# 2                  Highway 16 ditch near Tabor Nation                NaN
# 3              Whitefish (Goodfish) Lake First Nation                NaN
# 4   East of Prince Rupert on Highway 16, British C...                NaN
# 5                                Thunder Bay, Ontario                NaN
# 6   Haldi Road Elementary School, Prince George, B...                NaN
# 7                          Waywayseecapo First Nation                NaN
# 8    A hospital in Prince George, British Columbia...                NaN
# 9                                                 NaN                NaN
# 10                         Nisku, Alberta(No details)                NaN
# 11                                                NaN                NaN
# 12                                                NaN                NaN
# 13                             Near Westlock, Alberta                NaN
# 14  Pilot Mountain Subdivision, Outside Whitehorse...                NaN
# 15                                                NaN                NaN
# 16  Ditch on a rural road Surrey, British Columbia...                NaN
# 17                               Winnipeg's North End                NaN
# 18                                                NaN                NaN
# 19                                                NaN                NaN
# 20              Rideau River near the shelter, Ottawa                NaN
# 21                                                NaN                NaN
# 22                  Regent Hotel, Vancouver East Side                NaN
# 23                                Winnipeg, red river                NaN
#
#     Extra
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
#
# [24 rows x 27 columns]

# %%
df.loc[18]
# Out:
# Name                                                       Angeline Pete
# Age                                                                   28
# Province                                                              BC
# Status                                                           Missing
# First-Name                                                      Angeline
# Last-Name                                                           Pete
# LS-Latitude                                                    49.319871
# LS-Longitude                                                 -123.071587
# LS-Location Source     https://www.cbc.ca/missingandmurdered/mmiw/pro...
# F-Latitude                                                           0.0
# F-Longitude                                                          0.0
# F-Location Source                                                    NaN
# F-Year                                                                 0
# F-Month                                                                0
# F-Day                                                                  0
# LS-Year                                                             2011
# LS-Month                                                               5
# LS-Day                                                                26
# Highway-16                                                             0
# Serial Killer                                                          0
# Non-Dissapearance                                                      0
# LS-Location                                                          NaN
# F-Location                                                           NaN
# LS-General-Location                    North Vancouver, British Columbia
# F-General-Location                                                   NaN
# LS-Dubious Source                                                    NaN
# Extra                                                                NaN
# Name: 18, dtype: object

# %%
df.loc[18:28,'F-Latitude']
# Out:
# 18     0.000000
# 19          NaN
# 20    45.434145
# 21          NaN
# 22    49.286033
# 23    49.856241
# 24    49.768597
# 25    49.895261
# 26    54.089436
# 27    48.381011
# 28    53.207745
# Name: F-Latitude, dtype: float64

# %%
df.loc[18:28,'F-Longitude']
# Out:
# 18      0.000000
# 19           NaN
# 20    -75.672171
# 21           NaN
# 22   -123.120352
# 23    -97.125792
# 24    -94.507012
# 25    -97.147358
# 26    -97.752408
# 27    -89.268003
# 28   -105.826033
# Name: F-Longitude, dtype: float64

# %%
column_names = df.columns

# Display the column names
print(column_names)
# Out:
# Index(['Table 1'], dtype='object')
